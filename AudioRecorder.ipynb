# %%
# !pip install pyaudio
# Out:
# Collecting pyaudio
#   Using cached PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (pyproject.toml) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/admin/Desktop/Speech-Emotion-Analyzer-master/.venv/bin/python /Users/admin/Desktop/Speech-Emotion-Analyzer-master/.venv/lib/python3.7/site-packages/pip/_vendor/pep517/in_process/_in_process.py build_wheel /var/folders/_z/54vr9qxj46qb77h38c6xxf4c0000gn/T/tmpo4ysrw9k
#        cwd: /private/var/folders/_z/54vr9qxj46qb77h38c6xxf4c0000gn/T/pip-install-374peipn/pyaudio_9e7ab51261cc4491856b426fb1a4a9d8
#   Complete output (15 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-cpython-37
#   creating build/lib.macosx-10.9-x86_64-cpython-37/pyaudio
#   copying src/pyaudio/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-37/pyaudio
#   running build_ext
#   building 'pyaudio._portaudio' extension
#   creating build/temp.macosx-10.9-x86_64-cpython-37
#   creating build/temp.macosx-10.9-x86_64-cpython-37/src
#   creating build/temp.macosx-10.9-x86_64-cpython-37/src/pyaudio
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch x86_64 -g -DMACOS=1 -I/usr/local/include -I/usr/include -I/opt/homebrew/include -I/Users/admin/Desktop/Speech-Emotion-Analyzer-master/.venv/include -I/Library/Frameworks/Python.framework/Versions/3.7/include/python3.7m -c src/pyaudio/device_api.c -o build/temp.macosx-10.9-x86_64-cpython-37/src/pyaudio/device_api.o
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   error: command '/usr/bin/gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# ERROR: Could not build wheels for pyaudio, which is required to install pyproject.toml-based projects
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/Users/admin/Desktop/Speech-Emotion-Analyzer-master/.venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install wave
# Out:
# Requirement already satisfied: wave in ./.venv/lib/python3.7/site-packages (0.0.2)
# WARNING: You are using pip version 21.3.1; however, version 24.0 is available.
# You should consider upgrading via the '/Users/admin/Desktop/Speech-Emotion-Analyzer-master/.venv/bin/python -m pip install --upgrade pip' command.

# %%
import pyaudio
import wave

CHUNK = 1024 
FORMAT = pyaudio.paInt16 #paInt8
CHANNELS = 2 
RATE = 44100 #sample rate
RECORD_SECONDS = 4
WAVE_OUTPUT_FILENAME = "output10.wav"

p = pyaudio.PyAudio()

stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK) #buffer

print("* recording")

frames = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data) # 2 bytes(16 bits) per channel

print("* done recording")

stream.stop_stream()
stream.close()
p.terminate()

wf = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(p.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/_z/54vr9qxj46qb77h38c6xxf4c0000gn/T/ipykernel_51536/924716874.py in <module>
# ----> 1 import pyaudio
#       2 import wave
#       3
#       4 CHUNK = 1024
#       5 FORMAT = pyaudio.paInt16 #paInt8
#
# ModuleNotFoundError: No module named 'pyaudio'
